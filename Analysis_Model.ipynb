# %%
import pandas as pd
import numpy as np
# Out:
# Running cells with '.venv (3.12.11) (Python 3.12.11)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Aseel/Desktop/customer_segmentation/.venv/bin/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("customer_segmentation.csv")

# %%
df.head()
